# %% [markdown]
# #labels = ['furniture','electronic','pet','sports','food','travel','baby','kitchen','fashion','beauty']

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## <Class1 : furnitue>

# %%
Class1 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class1.csv')
Class1['Date'] = pd.date_range('2018-04-01', '2018-09-30').strftime('%Y-%m-%d')
Class1['Date'] =pd.to_datetime(Class1['Date'])
Class1 = Class1.set_index('Date')
Class1.head()
# Out:
#             BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  \
# Date
# 2018-04-01        1306      74.850340         1719.490868      35.022676
# 2018-04-02        2280      67.553411         1756.592258      34.607465
# 2018-04-03        1615      70.748404         1703.317481      34.291188
# 2018-04-04        2079      59.063566         1525.807812      34.294574
# 2018-04-05        4097      66.813036         1678.644214      34.150943
#
#             furniture
# Date
# 2018-04-01  88.000000
# 2018-04-02  88.000000
# 2018-04-03  83.111111
# 2018-04-04  83.111111
# 2018-04-05  80.666667

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    diff.append(dataset[0])
    for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
    return pd.Series(diff)

# inverse_difference
def inverse_difference(diff, interval=1):
    origin = list()
    origin.append(diff[0])
    for i in range(interval, len(diff)):
            value = diff[i] + origin[i - interval]
            origin.append(value)
    return pd.Series(origin)

# %%
Y = Class1['BUY_CT_sum']

# %%
#remove original Y
Class1.drop(columns=['BUY_CT_sum'],inplace=True)
Class1.rename(columns = {'furniture' : 'naver_click'}, inplace=True)
Class1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  naver_click
# Date
# 2018-04-01      74.850340         1719.490868      35.022676    88.000000
# 2018-04-02      67.553411         1756.592258      34.607465    88.000000
# 2018-04-03      70.748404         1703.317481      34.291188    83.111111
# 2018-04-04      59.063566         1525.807812      34.294574    83.111111
# 2018-04-05      66.813036         1678.644214      34.150943    80.666667

# %%
def minmax(dataset):
    dataNorm=((dataset-dataset.min())/(dataset.max()-dataset.min()))
    return dataNorm

def inverse_minmax(norm,dataset):
    deNorm=norm*(dataset.max()-dataset.min())+dataset.min()
    return deNorm

# %% [markdown]
# #### 변수 조합

# %%
#TOT_SESS_HR_V_mean 역수
Class1['TOT_SESS_HR_V_mean'] = 1000/Class1['TOT_SESS_HR_V_mean']
Class1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  naver_click
# Date
# 2018-04-01      74.850340            0.581567      35.022676    88.000000
# 2018-04-02      67.553411            0.569284      34.607465    88.000000
# 2018-04-03      70.748404            0.587090      34.291188    83.111111
# 2018-04-04      59.063566            0.655391      34.294574    83.111111
# 2018-04-05      66.813036            0.595719      34.150943    80.666667

# %% [markdown]
# #### scaled

# %%
scaled_df1=minmax(Class1)
#(xi–mean(x))/stdev(x)
scaled_df1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  naver_click
# Date
# 2018-04-01       0.342822            0.452474       0.509541     0.833333
# 2018-04-02       0.239338            0.413466       0.404708     0.833333
# 2018-04-03       0.284649            0.470010       0.324854     0.722222
# 2018-04-04       0.118936            0.686910       0.325709     0.722222
# 2018-04-05       0.228838            0.497414       0.289445     0.666667

# %%
scaled_Y = minmax(Y)

scaled_df1 = pd.concat([scaled_df1, scaled_Y], axis = 1)
scaled_df1.rename(columns={'BUY_CT_sum':'Y'}, inplace=True)

scaled_df1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  naver_click  \
# Date
# 2018-04-01       0.342822            0.452474       0.509541     0.833333
# 2018-04-02       0.239338            0.413466       0.404708     0.833333
# 2018-04-03       0.284649            0.470010       0.324854     0.722222
# 2018-04-04       0.118936            0.686910       0.325709     0.722222
# 2018-04-05       0.228838            0.497414       0.289445     0.666667
#
#                    Y
# Date
# 2018-04-01  0.273366
# 2018-04-02  0.526946
# 2018-04-03  0.353814
# 2018-04-04  0.474616
# 2018-04-05  1.000000

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
#original data
plot_acf(Y, ax = plt.gca())

# %% [markdown]
# #### modeling

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# C:\Users\wjssm\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#scaled_data : scaled한 데이터. 사용하려는 변수 + 마지막 칼럼은 Y
#n : 사용하는 변수 개수

scaled_data = scaled_df1
n = 4

# %%
scaled_Y = scaled_data['Y']

values = scaled_df1.values
# frame as supervised learning
reframed = series_to_supervised(scaled_df1, 1, 1)
reframed.drop(reframed.columns[-(n+1):-1], axis=1,inplace = True)

# split into train and test sets
values = reframed.values
n_train = int(len(scaled_data)*0.8)
train = values[:n_train, :]
test = values[n_train:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=25, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 3s - loss: 0.0844 - val_loss: 0.0611
# Epoch 2/300
#  - 0s - loss: 0.0628 - val_loss: 0.0442
# Epoch 3/300
#  - 0s - loss: 0.0464 - val_loss: 0.0328
# Epoch 4/300
#  - 0s - loss: 0.0352 - val_loss: 0.0262
# Epoch 5/300
#  - 0s - loss: 0.0284 - val_loss: 0.0234
# Epoch 6/300
#  - 0s - loss: 0.0252 - val_loss: 0.0232
# Epoch 7/300
#  - 0s - loss: 0.0242 - val_loss: 0.0239
# Epoch 8/300
#  - 0s - loss: 0.0240 - val_loss: 0.0245
# Epoch 9/300
#  - 0s - loss: 0.0240 - val_loss: 0.0246
# Epoch 10/300
#  - 0s - loss: 0.0238 - val_loss: 0.0242
# Epoch 11/300
#  - 0s - loss: 0.0236 - val_loss: 0.0238
# Epoch 12/300
#  - 0s - loss: 0.0235 - val_loss: 0.0235
# Epoch 13/300
#  - 0s - loss: 0.0234 - val_loss: 0.0233
# Epoch 14/300
#  - 0s - loss: 0.0234 - val_loss: 0.0232
# Epoch 15/300
#  - 0s - loss: 0.0234 - val_loss: 0.0232
# Epoch 16/300
#  - 0s - loss: 0.0234 - val_loss: 0.0232
# Epoch 17/300
#  - 0s - loss: 0.0233 - val_loss: 0.0232
# Epoch 18/300
#  - 0s - loss: 0.0232 - val_loss: 0.0233
# Epoch 19/300
#  - 0s - loss: 0.0232 - val_loss: 0.0233
# Epoch 20/300
#  - 0s - loss: 0.0231 - val_loss: 0.0233
# Epoch 21/300
#  - 0s - loss: 0.0231 - val_loss: 0.0233
# Epoch 22/300
#  - 0s - loss: 0.0230 - val_loss: 0.0233
# Epoch 23/300
#  - 0s - loss: 0.0230 - val_loss: 0.0233
# Epoch 24/300
#  - 0s - loss: 0.0229 - val_loss: 0.0233
# Epoch 25/300
#  - 0s - loss: 0.0229 - val_loss: 0.0233
# Epoch 26/300
#  - 0s - loss: 0.0229 - val_loss: 0.0233
# Epoch 27/300
#  - 0s - loss: 0.0228 - val_loss: 0.0233
# Epoch 28/300
#  - 0s - loss: 0.0228 - val_loss: 0.0233
# Epoch 29/300
#  - 0s - loss: 0.0227 - val_loss: 0.0233
# Epoch 30/300
#  - 0s - loss: 0.0227 - val_loss: 0.0233
# Epoch 31/300
#  - 0s - loss: 0.0227 - val_loss: 0.0233
# Epoch 32/300
#  - 0s - loss: 0.0226 - val_loss: 0.0233
# Epoch 33/300
#  - 0s - loss: 0.0226 - val_loss: 0.0234
# Epoch 34/300
#  - 0s - loss: 0.0226 - val_loss: 0.0234
# Epoch 35/300
#  - 0s - loss: 0.0225 - val_loss: 0.0234
# Epoch 36/300
#  - 0s - loss: 0.0225 - val_loss: 0.0234
# Epoch 37/300
#  - 0s - loss: 0.0225 - val_loss: 0.0234
# Epoch 38/300
#  - 0s - loss: 0.0225 - val_loss: 0.0235
# Epoch 39/300
#  - 0s - loss: 0.0224 - val_loss: 0.0235
# Epoch 40/300
#  - 0s - loss: 0.0224 - val_loss: 0.0235
# Epoch 41/300
#  - 0s - loss: 0.0224 - val_loss: 0.0235
# Epoch 42/300
#  - 0s - loss: 0.0224 - val_loss: 0.0236
# Epoch 43/300
#  - 0s - loss: 0.0223 - val_loss: 0.0236
# Epoch 44/300
#  - 0s - loss: 0.0223 - val_loss: 0.0236
# Epoch 45/300
#  - 0s - loss: 0.0223 - val_loss: 0.0237
# Epoch 46/300
#  - 0s - loss: 0.0223 - val_loss: 0.0237
# Epoch 47/300
#  - 0s - loss: 0.0222 - val_loss: 0.0237
# Epoch 48/300
#  - 0s - loss: 0.0222 - val_loss: 0.0238
# Epoch 49/300
#  - 0s - loss: 0.0222 - val_loss: 0.0238
# Epoch 50/300
#  - 0s - loss: 0.0222 - val_loss: 0.0238
# Epoch 51/300
#  - 0s - loss: 0.0222 - val_loss: 0.0239
# Epoch 52/300
#  - 0s - loss: 0.0222 - val_loss: 0.0239
# Epoch 53/300
#  - 0s - loss: 0.0221 - val_loss: 0.0240
# Epoch 54/300
#  - 0s - loss: 0.0221 - val_loss: 0.0240
# Epoch 55/300
#  - 0s - loss: 0.0221 - val_loss: 0.0240
# Epoch 56/300
#  - 0s - loss: 0.0221 - val_loss: 0.0241
# Epoch 57/300
#  - 0s - loss: 0.0221 - val_loss: 0.0241
# Epoch 58/300
#  - 0s - loss: 0.0221 - val_loss: 0.0242
# Epoch 59/300
#  - 0s - loss: 0.0221 - val_loss: 0.0242
# Epoch 60/300
#  - 0s - loss: 0.0221 - val_loss: 0.0242
# Epoch 61/300
#  - 0s - loss: 0.0220 - val_loss: 0.0243
# Epoch 62/300
#  - 0s - loss: 0.0220 - val_loss: 0.0243
# Epoch 63/300
#  - 0s - loss: 0.0220 - val_loss: 0.0244
# Epoch 64/300
#  - 0s - loss: 0.0220 - val_loss: 0.0244
# Epoch 65/300
#  - 0s - loss: 0.0220 - val_loss: 0.0244
# Epoch 66/300
#  - 0s - loss: 0.0220 - val_loss: 0.0245
# Epoch 67/300
#  - 0s - loss: 0.0220 - val_loss: 0.0245
# Epoch 68/300
#  - 0s - loss: 0.0220 - val_loss: 0.0246
# Epoch 69/300
#  - 0s - loss: 0.0220 - val_loss: 0.0246
# Epoch 70/300
#  - 0s - loss: 0.0220 - val_loss: 0.0247
# Epoch 71/300
#  - 0s - loss: 0.0220 - val_loss: 0.0247
# Epoch 72/300
#  - 0s - loss: 0.0220 - val_loss: 0.0247
# Epoch 73/300
#  - 0s - loss: 0.0220 - val_loss: 0.0248
# Epoch 74/300
#  - 0s - loss: 0.0219 - val_loss: 0.0248
# Epoch 75/300
#  - 0s - loss: 0.0219 - val_loss: 0.0249
# Epoch 76/300
#  - 0s - loss: 0.0219 - val_loss: 0.0249
# Epoch 77/300
#  - 0s - loss: 0.0219 - val_loss: 0.0249
# Epoch 78/300
#  - 0s - loss: 0.0219 - val_loss: 0.0250
# Epoch 79/300
#  - 0s - loss: 0.0219 - val_loss: 0.0250
# Epoch 80/300
#  - 0s - loss: 0.0219 - val_loss: 0.0251
# Epoch 81/300
#  - 0s - loss: 0.0219 - val_loss: 0.0251
# Epoch 82/300
#  - 0s - loss: 0.0219 - val_loss: 0.0251
# Epoch 83/300
#  - 0s - loss: 0.0219 - val_loss: 0.0252
# Epoch 84/300
#  - 0s - loss: 0.0219 - val_loss: 0.0252
# Epoch 85/300
#  - 0s - loss: 0.0219 - val_loss: 0.0252
# Epoch 86/300
#  - 0s - loss: 0.0219 - val_loss: 0.0253
# Epoch 87/300
#  - 0s - loss: 0.0219 - val_loss: 0.0253
# Epoch 88/300
#  - 0s - loss: 0.0219 - val_loss: 0.0254
# Epoch 89/300
#  - 0s - loss: 0.0219 - val_loss: 0.0254
# Epoch 90/300
#  - 0s - loss: 0.0219 - val_loss: 0.0254
# Epoch 91/300
#  - 0s - loss: 0.0219 - val_loss: 0.0255
# Epoch 92/300
#  - 0s - loss: 0.0219 - val_loss: 0.0255
# Epoch 93/300
#  - 0s - loss: 0.0219 - val_loss: 0.0255
# Epoch 94/300
#  - 0s - loss: 0.0219 - val_loss: 0.0256
# Epoch 95/300
#  - 0s - loss: 0.0219 - val_loss: 0.0256
# Epoch 96/300
#  - 0s - loss: 0.0219 - val_loss: 0.0256
# Epoch 97/300
#  - 0s - loss: 0.0219 - val_loss: 0.0257
# Epoch 98/300
#  - 0s - loss: 0.0219 - val_loss: 0.0257
# Epoch 99/300
#  - 0s - loss: 0.0219 - val_loss: 0.0257
# Epoch 100/300
#  - 0s - loss: 0.0219 - val_loss: 0.0258
# Epoch 101/300
#  - 0s - loss: 0.0218 - val_loss: 0.0258
# Epoch 102/300
#  - 0s - loss: 0.0218 - val_loss: 0.0258
# Epoch 103/300
#  - 0s - loss: 0.0218 - val_loss: 0.0259
# Epoch 104/300
#  - 0s - loss: 0.0218 - val_loss: 0.0259
# Epoch 105/300
#  - 0s - loss: 0.0218 - val_loss: 0.0259
# Epoch 106/300
#  - 0s - loss: 0.0218 - val_loss: 0.0259
# Epoch 107/300
#  - 0s - loss: 0.0218 - val_loss: 0.0260
# Epoch 108/300
#  - 0s - loss: 0.0218 - val_loss: 0.0260
# Epoch 109/300
#  - 0s - loss: 0.0218 - val_loss: 0.0260
# Epoch 110/300
#  - 0s - loss: 0.0218 - val_loss: 0.0261
# Epoch 111/300
#  - 0s - loss: 0.0218 - val_loss: 0.0261
# Epoch 112/300
#  - 0s - loss: 0.0218 - val_loss: 0.0261
# Epoch 113/300
#  - 0s - loss: 0.0218 - val_loss: 0.0261
# Epoch 114/300
#  - 0s - loss: 0.0218 - val_loss: 0.0262
# Epoch 115/300
#  - 0s - loss: 0.0218 - val_loss: 0.0262
# Epoch 116/300
#  - 0s - loss: 0.0218 - val_loss: 0.0262
# Epoch 117/300
#  - 0s - loss: 0.0218 - val_loss: 0.0262
# Epoch 118/300
#  - 0s - loss: 0.0218 - val_loss: 0.0263
# Epoch 119/300
#  - 0s - loss: 0.0218 - val_loss: 0.0263
# Epoch 120/300
#  - 0s - loss: 0.0218 - val_loss: 0.0263
# Epoch 121/300
#  - 0s - loss: 0.0218 - val_loss: 0.0263
# Epoch 122/300
#  - 0s - loss: 0.0218 - val_loss: 0.0264
# Epoch 123/300
#  - 0s - loss: 0.0218 - val_loss: 0.0264
# Epoch 124/300
#  - 0s - loss: 0.0218 - val_loss: 0.0264
# Epoch 125/300
#  - 0s - loss: 0.0218 - val_loss: 0.0264
# Epoch 126/300
#  - 0s - loss: 0.0218 - val_loss: 0.0265
# Epoch 127/300
#  - 0s - loss: 0.0218 - val_loss: 0.0265
# Epoch 128/300
#  - 0s - loss: 0.0218 - val_loss: 0.0265
# Epoch 129/300
#  - 0s - loss: 0.0218 - val_loss: 0.0265
# Epoch 130/300
#  - 0s - loss: 0.0218 - val_loss: 0.0266
# Epoch 131/300
#  - 0s - loss: 0.0218 - val_loss: 0.0266
# Epoch 132/300
#  - 0s - loss: 0.0218 - val_loss: 0.0266
# Epoch 133/300
#  - 0s - loss: 0.0218 - val_loss: 0.0266
# Epoch 134/300
#  - 0s - loss: 0.0218 - val_loss: 0.0266
# Epoch 135/300
#  - 0s - loss: 0.0218 - val_loss: 0.0267
# Epoch 136/300
#  - 0s - loss: 0.0218 - val_loss: 0.0267
# Epoch 137/300
#  - 0s - loss: 0.0218 - val_loss: 0.0267
# Epoch 138/300
#  - 0s - loss: 0.0218 - val_loss: 0.0267
# Epoch 139/300
#  - 0s - loss: 0.0218 - val_loss: 0.0267
# Epoch 140/300
#  - 0s - loss: 0.0218 - val_loss: 0.0268
# Epoch 141/300
#  - 0s - loss: 0.0218 - val_loss: 0.0268
# Epoch 142/300
#  - 0s - loss: 0.0218 - val_loss: 0.0268
# Epoch 143/300
#  - 0s - loss: 0.0218 - val_loss: 0.0268
# Epoch 144/300
#  - 0s - loss: 0.0218 - val_loss: 0.0268
# Epoch 145/300
#  - 0s - loss: 0.0218 - val_loss: 0.0269
# Epoch 146/300
#  - 0s - loss: 0.0218 - val_loss: 0.0269
# Epoch 147/300
#  - 0s - loss: 0.0218 - val_loss: 0.0269
# Epoch 148/300
#  - 0s - loss: 0.0218 - val_loss: 0.0269
# Epoch 149/300
#  - 0s - loss: 0.0218 - val_loss: 0.0269
# Epoch 150/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 151/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 152/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 153/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 154/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 155/300
#  - 0s - loss: 0.0218 - val_loss: 0.0270
# Epoch 156/300
#  - 0s - loss: 0.0218 - val_loss: 0.0271
# Epoch 157/300
#  - 0s - loss: 0.0218 - val_loss: 0.0271
# Epoch 158/300
#  - 0s - loss: 0.0217 - val_loss: 0.0271
# Epoch 159/300
#  - 0s - loss: 0.0217 - val_loss: 0.0271
# Epoch 160/300
#  - 0s - loss: 0.0217 - val_loss: 0.0271
# Epoch 161/300
#  - 0s - loss: 0.0217 - val_loss: 0.0271
# Epoch 162/300
#  - 0s - loss: 0.0217 - val_loss: 0.0272
# Epoch 163/300
#  - 0s - loss: 0.0217 - val_loss: 0.0272
# Epoch 164/300
#  - 0s - loss: 0.0217 - val_loss: 0.0272
# Epoch 165/300
#  - 0s - loss: 0.0217 - val_loss: 0.0272
# Epoch 166/300
#  - 0s - loss: 0.0217 - val_loss: 0.0272
# Epoch 167/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 168/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 169/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 170/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 171/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 172/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 173/300
#  - 0s - loss: 0.0217 - val_loss: 0.0273
# Epoch 174/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 175/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 176/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 177/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 178/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 179/300
#  - 0s - loss: 0.0217 - val_loss: 0.0274
# Epoch 180/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 181/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 182/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 183/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 184/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 185/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 186/300
#  - 0s - loss: 0.0217 - val_loss: 0.0275
# Epoch 187/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 188/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 189/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 190/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 191/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 192/300
#  - 0s - loss: 0.0217 - val_loss: 0.0276
# Epoch 193/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 194/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 195/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 196/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 197/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 198/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 199/300
#  - 0s - loss: 0.0217 - val_loss: 0.0277
# Epoch 200/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 201/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 202/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 203/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 204/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 205/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 206/300
#  - 0s - loss: 0.0217 - val_loss: 0.0278
# Epoch 207/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 208/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 209/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 210/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 211/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 212/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 213/300
#  - 0s - loss: 0.0217 - val_loss: 0.0279
# Epoch 214/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 215/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 216/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 217/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 218/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 219/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 220/300
#  - 0s - loss: 0.0217 - val_loss: 0.0280
# Epoch 221/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 222/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 223/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 224/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 225/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 226/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 227/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 228/300
#  - 0s - loss: 0.0217 - val_loss: 0.0281
# Epoch 229/300
#  - 0s - loss: 0.0217 - val_loss: 0.0282
# Epoch 230/300
#  - 0s - loss: 0.0217 - val_loss: 0.0282
# Epoch 231/300
#  - 0s - loss: 0.0217 - val_loss: 0.0282
# Epoch 232/300
#  - 0s - loss: 0.0216 - val_loss: 0.0282
# Epoch 233/300
#  - 0s - loss: 0.0216 - val_loss: 0.0282
# Epoch 234/300
#  - 0s - loss: 0.0216 - val_loss: 0.0282
# Epoch 235/300
#  - 0s - loss: 0.0216 - val_loss: 0.0282
# Epoch 236/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 237/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 238/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 239/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 240/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 241/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 242/300
#  - 0s - loss: 0.0216 - val_loss: 0.0283
# Epoch 243/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 244/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 245/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 246/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 247/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 248/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 249/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 250/300
#  - 0s - loss: 0.0216 - val_loss: 0.0284
# Epoch 251/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 252/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 253/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 254/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 255/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 256/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 257/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 258/300
#  - 0s - loss: 0.0216 - val_loss: 0.0285
# Epoch 259/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 260/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 261/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 262/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 263/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 264/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 265/300
#  - 0s - loss: 0.0216 - val_loss: 0.0286
# Epoch 266/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 267/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 268/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 269/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 270/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 271/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 272/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 273/300
#  - 0s - loss: 0.0216 - val_loss: 0.0287
# Epoch 274/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 275/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 276/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 277/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 278/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 279/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 280/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 281/300
#  - 0s - loss: 0.0216 - val_loss: 0.0288
# Epoch 282/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 283/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 284/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 285/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 286/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 287/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 288/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 289/300
#  - 0s - loss: 0.0216 - val_loss: 0.0289
# Epoch 290/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 291/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 292/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 293/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 294/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 295/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 296/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 297/300
#  - 0s - loss: 0.0216 - val_loss: 0.0290
# Epoch 298/300
#  - 0s - loss: 0.0216 - val_loss: 0.0291
# Epoch 299/300
#  - 0s - loss: 0.0216 - val_loss: 0.0291
# Epoch 300/300
#  - 0s - loss: 0.0216 - val_loss: 0.0291

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
true_Y = Y.values[n_train+1:].reshape(yhat.shape[0],1)

# %%
# invert scaling for forecast
dfhat = np.concatenate((true_Y,yhat), axis = 1)
#inv_dfhat = scaler.inverse_transform(dfhat)
inv_yhat = inverse_minmax(dfhat[:,1],dfhat[:,0])

# calculate RMSE
rmse = np.sqrt(mean_squared_error(true_Y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 572.383

# %%
plt.plot(true_Y, label = 'y_true')
plt.plot(inv_yhat,label = 'y_hat')
plt.legend()

# %%
inv_yhat = pd.Series(inv_yhat)
inv_yhat.index = Y[n_train+1:,].index

# %%
plt.plot(Y, label = 'y_true')
plt.plot(inv_yhat,label = 'y_hat', c='r')
plt.legend()
