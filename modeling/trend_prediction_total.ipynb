# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
labels = ['furniture','electronic','pet','sports','food','travel','baby','kitchen','fashion','beauty']

# %%
Class1 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class1.csv')
Class2 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class2.csv')
Class3 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class3.csv')
Class4 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class4.csv')
Class5 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class5.csv')
Class6 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class6.csv')
Class7 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class7.csv')
Class8 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class8.csv')
Class9 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class9.csv')
Class10 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class10.csv')

# %%
#index
mydate = pd.date_range('2018-04-01', '2018-09-30').strftime('%Y-%m-%d')

Class1.index = mydate
Class2.index = mydate
Class3.index = mydate
Class4.index = mydate
Class5.index = mydate
Class6.index = mydate
Class7.index = mydate
Class8.index = mydate
Class9.index = mydate
Class10.index = mydate

# %%
BUY_sum = [None]*10
BUY_sum[0] = Class1['BUY_CT_sum'].sum()
BUY_sum[1] = Class2['BUY_CT_sum'].sum()
BUY_sum[2] = Class3['BUY_CT_sum'].sum()
BUY_sum[3] = Class4['BUY_CT_sum'].sum()
BUY_sum[4] = Class5['BUY_CT_sum'].sum()
BUY_sum[5] = Class6['BUY_CT_sum'].sum()
BUY_sum[6] = Class7['BUY_CT_sum'].sum()
BUY_sum[7] = Class8['BUY_CT_sum'].sum()
BUY_sum[8] = Class9['BUY_CT_sum'].sum()
BUY_sum[9] = Class10['BUY_CT_sum'].sum()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.pie(BUY_sum, labels = labels, autopct='%1.1f%%')
plt.show()

# %%
Class1.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  furniture
# 0        1306      74.850340         1719.490868      35.022676  88.000000
# 1        2280      67.553411         1756.592258      34.607465  88.000000
# 2        1615      70.748404         1703.317481      34.291188  83.111111
# 3        2079      59.063566         1525.807812      34.294574  83.111111
# 4        4097      66.813036         1678.644214      34.150943  80.666667

# %%
Class2.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  electronic
# 0         693      68.443769         1490.337920      34.270517  173.555556
# 1         648      58.410543         1442.700965      34.440895  183.333333
# 2         623      62.658759         1425.818182      33.430657  178.444444
# 3         611      62.197880         1386.578097      33.975265  176.000000
# 4         530      60.585921         1443.321577      34.327122  166.222222

# %%
Class3.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  pet
# 0         640      76.411111         1447.200000      35.722222    7
# 1         813      81.136187         1579.470356      34.299611    7
# 2         548      67.900312         1302.501567      35.451713    7
# 3         662      64.913747         1592.352113      35.687332    7
# 4         667      80.014583         1499.563941      34.958333    7

# %%
Class4.drop(columns = ['SESS_DT','moving3','Temperature','Rainfall'], inplace=True)
Class4.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean     sports
# 0        4966      84.227786         1716.971662      34.664394  86.705882
# 1        4451      82.752833         1621.644756      35.009443  88.000000
# 2        3867      79.802024         1632.115778      35.206453  86.705882
# 3        3701      89.588137         1812.495346      35.833800  84.117647
# 4        3701      89.588137         1812.495346      35.833800  80.235294

# %%
Class5.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean       food
# 0        1422      61.259669         1360.637375      35.690608  49.176471
# 1        1535      59.834630         1259.893346      35.194553  54.352941
# 2        1295      55.008859         1152.022198      35.204873  54.352941
# 3        1370      48.867631         1050.995501      34.994438  56.941176
# 4        1542      61.868687         1290.596154      35.454545  55.647059

# %%
Class6.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  travel
# 0          66      49.035088          904.631579      31.578947      21
# 1          69      34.304348          796.891304      31.304348      21
# 2          75      30.627119          664.462963      33.050847      21
# 3          48      24.378378          859.944444      31.081081      20
# 4          65      37.696429          819.222222      31.071429      21

# %%
Class7.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  baby
# 0        4084     107.210021         1889.611719      34.112150    71
# 1        4210      96.258771         1746.693213      33.722319    75
# 2        4728     101.467716         1851.887689      34.013233    74
# 3        3943      98.091009         1778.964325      33.846577    74
# 4        3555      88.247506         1652.669360      33.604763    73

# %%
Class8.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean     kitchen
# 0        1995      75.125000         1653.928679      35.157186  112.933333
# 1        1910      65.013571         1505.189787      35.250212  126.133333
# 2        2036      76.665635         1659.884914      35.386997  123.200000
# 3        1419      60.346078         1288.602362      34.333333  126.133333
# 4        1946      66.628085         1465.965870      34.936170  121.733333

# %%
Class9.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean     fashion
# 0       15446     107.008910         1958.732921      34.931247  383.777778
# 1       13338      91.290241         1738.117266      34.622027  356.888889
# 2       13514      94.545942         1776.986599      34.835746  349.555556
# 3       12405      88.670594         1651.527270      34.530426  339.777778
# 4       11739      90.039054         1731.360890      35.380734  325.111111

# %%
Class10.head()
# Out:
#    BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  beauty
# 0        5249      76.096409         1723.511683      32.312954      44
# 1        4396      66.356552         1404.668366      32.271150      44
# 2        3532      66.140059         1417.485087      32.288606      44
# 3        3674      58.337224         1334.197519      32.172503      44
# 4        3294      65.217039         1498.213533      32.261663      41

# %%
import matplotlib.pyplot as plt

# %%
labels = ['furniture','electronic','pet','sports','food','travel','baby','kitchen','fashion','beauty']

# %%
fig = plt.figure(figsize = (20,10))
fig.suptitle('Daily PD_BUY_CT sum', fontsize=25)

plt.plot(Class1['BUY_CT_sum'], label = labels[0])
plt.plot(Class2['BUY_CT_sum'], label = labels[1])
plt.plot(Class3['BUY_CT_sum'], label = labels[2])
plt.plot(Class4['BUY_CT_sum'], label = labels[3])
plt.plot(Class5['BUY_CT_sum'], label = labels[4])
plt.plot(Class6['BUY_CT_sum'], label = labels[5])
plt.plot(Class7['BUY_CT_sum'], label = labels[6])
plt.plot(Class8['BUY_CT_sum'], label = labels[7])
plt.plot(Class9['BUY_CT_sum'], label = labels[8])
plt.plot(Class10['BUY_CT_sum'], label = labels[9])
plt.xticks(['2018-04-01','2018-04-15','2018-05-01','2018-05-15','2018-06-01','2018-06-15',
            '2018-07-01','2018-07-15','2018-08-01','2018-08-15','2018-09-01','2018-09-15'], fontsize = 12)

plt.legend(fontsize="x-large", ncol = 2)

# %%
fig = plt.figure(figsize = (20,10))
fig.suptitle('Daily PD_BUY_CT sum percentage(%)', fontsize=25)

plt.plot(Class1['BUY_CT_sum']/Class1['BUY_CT_sum'].sum()*100, label = labels[0])
plt.plot(Class2['BUY_CT_sum']/Class2['BUY_CT_sum'].sum()*100, label = labels[1])
plt.plot(Class3['BUY_CT_sum']/Class3['BUY_CT_sum'].sum()*100, label = labels[2])
plt.plot(Class4['BUY_CT_sum']/Class4['BUY_CT_sum'].sum()*100, label = labels[3])
plt.plot(Class5['BUY_CT_sum']/Class5['BUY_CT_sum'].sum()*100, label = labels[4])
plt.plot(Class6['BUY_CT_sum']/Class6['BUY_CT_sum'].sum()*100, label = labels[5])
plt.plot(Class7['BUY_CT_sum']/Class7['BUY_CT_sum'].sum()*100, label = labels[6])
plt.plot(Class8['BUY_CT_sum']/Class8['BUY_CT_sum'].sum()*100, label = labels[7])
plt.plot(Class9['BUY_CT_sum']/Class9['BUY_CT_sum'].sum()*100, label = labels[8])
plt.plot(Class10['BUY_CT_sum']/Class10['BUY_CT_sum'].sum()*100, label = labels[9])
plt.xticks(['2018-04-01','2018-04-15','2018-05-01','2018-05-15','2018-06-01','2018-06-15',
            '2018-07-01','2018-07-15','2018-08-01','2018-08-15','2018-09-01','2018-09-15'], fontsize = 12)

plt.legend(fontsize="x-large", ncol = 2)

# %% [markdown]
# ### total preprocessing

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    diff.append(dataset[0])
    for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
    return pd.Series(diff)

# inverse_difference
def inverse_difference(diff, interval=1):
    origin = list()
    origin.append(diff[0])
    for i in range(interval, len(diff)):
            value = diff[i] + origin[i - interval]
            origin.append(value)
    return pd.Series(origin)

def minmax(dataset):
    dataNorm=((dataset-dataset.min())/(dataset.max()-dataset.min()))
    return dataNorm

def inverse_minmax(norm,dataset):
    deNorm=norm*(dataset.max()-dataset.min())+dataset.min()
    return deNorm

# %%
Y1 = Class1['BUY_CT_sum']
Y2 = Class2['BUY_CT_sum']
Y3 = Class3['BUY_CT_sum']
Y4 = Class4['BUY_CT_sum']
Y5 = Class5['BUY_CT_sum']
Y6 = Class6['BUY_CT_sum']
Y7 = Class7['BUY_CT_sum']
Y8 = Class8['BUY_CT_sum']
Y9 = Class9['BUY_CT_sum']
Y10 = Class10['BUY_CT_sum']

# %%
labels
# Out:
# ['furniture',
#  'electronic',
#  'pet',
#  'sports',
#  'food',
#  'travel',
#  'baby',
#  'kitchen',
#  'fashion',
#  'beauty']

# %%
#remove original Y
Class1.drop(columns=['BUY_CT_sum'],inplace=True)
Class1.rename(columns = {'furniture' : 'naver_click'}, inplace=True)

Class2.drop(columns=['BUY_CT_sum'],inplace=True)
Class2.rename(columns = {'electronic' : 'naver_click'}, inplace=True)

Class3.drop(columns=['BUY_CT_sum'],inplace=True)
Class3.rename(columns = {'pet' : 'naver_click'}, inplace=True)

Class4.drop(columns=['BUY_CT_sum'],inplace=True)
Class4.rename(columns = {'sports' : 'naver_click'}, inplace=True)

Class5.drop(columns=['BUY_CT_sum'],inplace=True)
Class5.rename(columns = {'food' : 'naver_click'}, inplace=True)

Class6.drop(columns=['BUY_CT_sum'],inplace=True)
Class6.rename(columns = {'travel' : 'naver_click'}, inplace=True)

Class7.drop(columns=['BUY_CT_sum'],inplace=True)
Class7.rename(columns = {'baby' : 'naver_click'}, inplace=True)

Class8.drop(columns=['BUY_CT_sum'],inplace=True)
Class8.rename(columns = {'kitchen' : 'naver_click'}, inplace=True)

Class9.drop(columns=['BUY_CT_sum'],inplace=True)
Class9.rename(columns = {'fashion' : 'naver_click'}, inplace=True)

Class10.drop(columns=['BUY_CT_sum'],inplace=True)
Class10.rename(columns = {'beauty' : 'naver_click'}, inplace=True)

# %%
#TOT_SESS_HR_V_mean 역수
Class1['TOT_SESS_HR_V_mean'] = 1000/Class1['TOT_SESS_HR_V_mean']
Class2['TOT_SESS_HR_V_mean'] = 1000/Class2['TOT_SESS_HR_V_mean']
Class3['TOT_SESS_HR_V_mean'] = 1000/Class3['TOT_SESS_HR_V_mean']
Class4['TOT_SESS_HR_V_mean'] = 1000/Class4['TOT_SESS_HR_V_mean']
Class5['TOT_SESS_HR_V_mean'] = 1000/Class5['TOT_SESS_HR_V_mean']
Class6['TOT_SESS_HR_V_mean'] = 1000/Class6['TOT_SESS_HR_V_mean']
Class7['TOT_SESS_HR_V_mean'] = 1000/Class7['TOT_SESS_HR_V_mean']
Class8['TOT_SESS_HR_V_mean'] = 1000/Class8['TOT_SESS_HR_V_mean']
Class9['TOT_SESS_HR_V_mean'] = 1000/Class9['TOT_SESS_HR_V_mean']
Class10['TOT_SESS_HR_V_mean'] = 1000/Class10['TOT_SESS_HR_V_mean']

# %%
Class3.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  naver_click
# 2018-04-01      76.411111            0.690989      35.722222            7
# 2018-04-02      81.136187            0.633124      34.299611            7
# 2018-04-03      67.900312            0.767753      35.451713            7
# 2018-04-04      64.913747            0.628002      35.687332            7
# 2018-04-05      80.014583            0.666861      34.958333            7

# %%
Class4.drop(columns = ['SESS_DT','moving3','Temperature','Rainfall'], inplace=True)

# %% [markdown]
# ### total modeling

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# C:\Users\wjssm\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def lstm_model(class_data, y) :
    
    scaled_df1=minmax(class_data)
    scaled_Y = minmax(y)

    scaled_df1 = pd.concat([scaled_df1, scaled_Y], axis = 1)
    scaled_df1.rename(columns={'BUY_CT_sum':'Y'}, inplace=True)
    
    
    def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    
        n_vars = 1 if type(data) is list else data.shape[1]
        df = pd.DataFrame(data)
        cols, names = list(), list()
        # input sequence (t-n, ... t-1)
        for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

        # forecast sequence (t, t+1, ... t+n)
        for i in range(0, n_out):
            cols.append(df.shift(-i))
            if i == 0:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

        # put it all together
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        # drop rows with NaN values
        if dropnan:
            agg.dropna(inplace=True)
        return agg
    
    scaled_Y = scaled_df1['Y']

    n=4 #the number of variables
    values = scaled_df1.values
    # frame as supervised learning
    reframed = series_to_supervised(scaled_df1, 1, 1)
    reframed.drop(reframed.columns[-(n+1):-1], axis=1,inplace = True)

    # split into train and test sets
    values = reframed.values
    n_train = int(len(scaled_df1)*0.8)
    train = values[:n_train, :]
    test = values[n_train:, :]
    # split into input and outputs
    train_X, train_y = train[:, :-1], train[:, -1]
    test_X, test_y = test[:, :-1], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.add(Dropout(0.2))
    model.compile(loss='mse', optimizer='adam')
    # fit network
    history = model.fit(train_X, train_y, epochs=300, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False)
    
    # make a prediction
    yhat = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    true_Y = y.values[n_train+1:].reshape(yhat.shape[0],1)
    
    # invert scaling for forecast
    dfhat = np.concatenate((true_Y,yhat), axis = 1)
    #inv_dfhat = scaler.inverse_transform(dfhat)
    inv_yhat = inverse_minmax(dfhat[:,1],dfhat[:,0])

    # calculate RMSE
    rmse = np.sqrt(mean_squared_error(true_Y, inv_yhat))
    #print('Test RMSE: %.3f' % rmse)
    
    inv_yhat = pd.Series(inv_yhat)
    inv_yhat.index = y[n_train+1:,].index
    
    return inv_yhat

# %%
labels
# Out:
# ['furniture',
#  'electronic',
#  'pet',
#  'sports',
#  'food',
#  'travel',
#  'baby',
#  'kitchen',
#  'fashion',
#  'beauty']

# %%
y1_pred = lstm_model(Class1, Y1)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.0716 - val_loss: 0.0525
# Epoch 2/300
#  - 0s - loss: 0.0629 - val_loss: 0.0448
# Epoch 3/300
#  - 0s - loss: 0.0532 - val_loss: 0.0384
# Epoch 4/300
#  - 0s - loss: 0.0443 - val_loss: 0.0332
# Epoch 5/300
#  - 0s - loss: 0.0436 - val_loss: 0.0293
# Epoch 6/300
#  - 0s - loss: 0.0362 - val_loss: 0.0265
# Epoch 7/300
#  - 0s - loss: 0.0332 - val_loss: 0.0246
# Epoch 8/300
#  - 0s - loss: 0.0354 - val_loss: 0.0236
# Epoch 9/300
#  - 0s - loss: 0.0264 - val_loss: 0.0231
# Epoch 10/300
#  - 0s - loss: 0.0307 - val_loss: 0.0231
# Epoch 11/300
#  - 0s - loss: 0.0298 - val_loss: 0.0231
# Epoch 12/300
#  - 0s - loss: 0.0331 - val_loss: 0.0232
# Epoch 13/300
#  - 0s - loss: 0.0328 - val_loss: 0.0232
# Epoch 14/300
#  - 0s - loss: 0.0328 - val_loss: 0.0231
# Epoch 15/300
#  - 0s - loss: 0.0313 - val_loss: 0.0230
# Epoch 16/300
#  - 0s - loss: 0.0320 - val_loss: 0.0229
# Epoch 17/300
# ...

# %%
y2_pred = lstm_model(Class2, Y2)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.3109 - val_loss: 0.1192
# Epoch 2/300
#  - 0s - loss: 0.2761 - val_loss: 0.1019
# Epoch 3/300
#  - 0s - loss: 0.2491 - val_loss: 0.0867
# Epoch 4/300
#  - 0s - loss: 0.2203 - val_loss: 0.0732
# Epoch 5/300
#  - 0s - loss: 0.2010 - val_loss: 0.0616
# Epoch 6/300
#  - 0s - loss: 0.1803 - val_loss: 0.0516
# Epoch 7/300
#  - 0s - loss: 0.1593 - val_loss: 0.0432
# Epoch 8/300
#  - 0s - loss: 0.1397 - val_loss: 0.0364
# Epoch 9/300
#  - 0s - loss: 0.1136 - val_loss: 0.0309
# Epoch 10/300
#  - 0s - loss: 0.0972 - val_loss: 0.0267
# Epoch 11/300
#  - 0s - loss: 0.1291 - val_loss: 0.0239
# Epoch 12/300
#  - 0s - loss: 0.1001 - val_loss: 0.0223
# Epoch 13/300
#  - 0s - loss: 0.0850 - val_loss: 0.0217
# Epoch 14/300
#  - 0s - loss: 0.0820 - val_loss: 0.0219
# Epoch 15/300
#  - 0s - loss: 0.0719 - val_loss: 0.0226
# Epoch 16/300
#  - 0s - loss: 0.0881 - val_loss: 0.0238
# Epoch 17/300
# ...

# %%
y3_pred = lstm_model(Class3, Y3)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.2005 - val_loss: 0.1023
# Epoch 2/300
#  - 0s - loss: 0.1783 - val_loss: 0.0861
# Epoch 3/300
#  - 0s - loss: 0.1599 - val_loss: 0.0716
# Epoch 4/300
#  - 0s - loss: 0.1404 - val_loss: 0.0589
# Epoch 5/300
#  - 0s - loss: 0.1189 - val_loss: 0.0477
# Epoch 6/300
#  - 0s - loss: 0.1126 - val_loss: 0.0381
# Epoch 7/300
#  - 0s - loss: 0.0950 - val_loss: 0.0302
# Epoch 8/300
#  - 0s - loss: 0.0868 - val_loss: 0.0237
# Epoch 9/300
#  - 0s - loss: 0.0806 - val_loss: 0.0188
# Epoch 10/300
#  - 0s - loss: 0.0635 - val_loss: 0.0152
# Epoch 11/300
#  - 0s - loss: 0.0749 - val_loss: 0.0129
# Epoch 12/300
#  - 0s - loss: 0.0559 - val_loss: 0.0117
# Epoch 13/300
#  - 0s - loss: 0.0526 - val_loss: 0.0112
# Epoch 14/300
#  - 0s - loss: 0.0485 - val_loss: 0.0114
# Epoch 15/300
#  - 0s - loss: 0.0437 - val_loss: 0.0120
# Epoch 16/300
#  - 0s - loss: 0.0443 - val_loss: 0.0127
# Epoch 17/300
# ...

# %%
y4_pred = lstm_model(Class4, Y4)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.2194 - val_loss: 0.0604
# Epoch 2/300
#  - 0s - loss: 0.1982 - val_loss: 0.0506
# Epoch 3/300
#  - 0s - loss: 0.1789 - val_loss: 0.0421
# Epoch 4/300
#  - 0s - loss: 0.1691 - val_loss: 0.0348
# Epoch 5/300
#  - 0s - loss: 0.1496 - val_loss: 0.0286
# Epoch 6/300
#  - 0s - loss: 0.1324 - val_loss: 0.0235
# Epoch 7/300
#  - 0s - loss: 0.1245 - val_loss: 0.0195
# Epoch 8/300
#  - 0s - loss: 0.1042 - val_loss: 0.0166
# Epoch 9/300
#  - 0s - loss: 0.1140 - val_loss: 0.0148
# Epoch 10/300
#  - 0s - loss: 0.0965 - val_loss: 0.0139
# Epoch 11/300
#  - 0s - loss: 0.0935 - val_loss: 0.0138
# Epoch 12/300
#  - 0s - loss: 0.0939 - val_loss: 0.0144
# Epoch 13/300
#  - 0s - loss: 0.0761 - val_loss: 0.0153
# Epoch 14/300
#  - 0s - loss: 0.0922 - val_loss: 0.0165
# Epoch 15/300
#  - 0s - loss: 0.0840 - val_loss: 0.0178
# Epoch 16/300
#  - 0s - loss: 0.0698 - val_loss: 0.0190
# Epoch 17/300
# ...

# %%
y5_pred = lstm_model(Class5, Y5)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.0676 - val_loss: 0.1603
# Epoch 2/300
#  - 0s - loss: 0.0552 - val_loss: 0.1416
# Epoch 3/300
#  - 0s - loss: 0.0444 - val_loss: 0.1249
# Epoch 4/300
#  - 0s - loss: 0.0371 - val_loss: 0.1103
# Epoch 5/300
#  - 0s - loss: 0.0301 - val_loss: 0.0976
# Epoch 6/300
#  - 0s - loss: 0.0250 - val_loss: 0.0868
# Epoch 7/300
#  - 0s - loss: 0.0194 - val_loss: 0.0778
# Epoch 8/300
#  - 0s - loss: 0.0200 - val_loss: 0.0705
# Epoch 9/300
#  - 0s - loss: 0.0208 - val_loss: 0.0650
# Epoch 10/300
#  - 0s - loss: 0.0144 - val_loss: 0.0609
# Epoch 11/300
#  - 0s - loss: 0.0131 - val_loss: 0.0580
# Epoch 12/300
#  - 0s - loss: 0.0150 - val_loss: 0.0561
# Epoch 13/300
#  - 0s - loss: 0.0175 - val_loss: 0.0552
# Epoch 14/300
#  - 0s - loss: 0.0154 - val_loss: 0.0549
# Epoch 15/300
#  - 0s - loss: 0.0171 - val_loss: 0.0551
# Epoch 16/300
#  - 0s - loss: 0.0174 - val_loss: 0.0557
# Epoch 17/300
# ...

# %%
y6_pred = lstm_model(Class6, Y6)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.0833 - val_loss: 0.0305
# Epoch 2/300
#  - 0s - loss: 0.0709 - val_loss: 0.0234
# Epoch 3/300
#  - 0s - loss: 0.0590 - val_loss: 0.0177
# Epoch 4/300
#  - 0s - loss: 0.0504 - val_loss: 0.0133
# Epoch 5/300
#  - 0s - loss: 0.0498 - val_loss: 0.0104
# Epoch 6/300
#  - 0s - loss: 0.0500 - val_loss: 0.0086
# Epoch 7/300
#  - 0s - loss: 0.0381 - val_loss: 0.0076
# Epoch 8/300
#  - 0s - loss: 0.0346 - val_loss: 0.0072
# Epoch 9/300
#  - 0s - loss: 0.0384 - val_loss: 0.0071
# Epoch 10/300
#  - 0s - loss: 0.0385 - val_loss: 0.0072
# Epoch 11/300
#  - 0s - loss: 0.0341 - val_loss: 0.0073
# Epoch 12/300
#  - 0s - loss: 0.0430 - val_loss: 0.0074
# Epoch 13/300
#  - 0s - loss: 0.0407 - val_loss: 0.0074
# Epoch 14/300
#  - 0s - loss: 0.0415 - val_loss: 0.0073
# Epoch 15/300
#  - 0s - loss: 0.0468 - val_loss: 0.0072
# Epoch 16/300
#  - 0s - loss: 0.0398 - val_loss: 0.0071
# Epoch 17/300
# ...

# %%
y7_pred = lstm_model(Class7, Y7)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.1131 - val_loss: 0.0958
# Epoch 2/300
#  - 0s - loss: 0.0996 - val_loss: 0.0842
# Epoch 3/300
#  - 0s - loss: 0.0907 - val_loss: 0.0740
# Epoch 4/300
#  - 0s - loss: 0.0861 - val_loss: 0.0651
# Epoch 5/300
#  - 0s - loss: 0.0722 - val_loss: 0.0572
# Epoch 6/300
#  - 0s - loss: 0.0658 - val_loss: 0.0504
# Epoch 7/300
#  - 0s - loss: 0.0623 - val_loss: 0.0446
# Epoch 8/300
#  - 0s - loss: 0.0566 - val_loss: 0.0398
# Epoch 9/300
#  - 0s - loss: 0.0589 - val_loss: 0.0359
# Epoch 10/300
#  - 0s - loss: 0.0504 - val_loss: 0.0328
# Epoch 11/300
#  - 0s - loss: 0.0512 - val_loss: 0.0303
# Epoch 12/300
#  - 0s - loss: 0.0495 - val_loss: 0.0284
# Epoch 13/300
#  - 0s - loss: 0.0538 - val_loss: 0.0270
# Epoch 14/300
#  - 0s - loss: 0.0506 - val_loss: 0.0260
# Epoch 15/300
#  - 0s - loss: 0.0457 - val_loss: 0.0252
# Epoch 16/300
#  - 0s - loss: 0.0537 - val_loss: 0.0247
# Epoch 17/300
# ...

# %%
y8_pred = lstm_model(Class8, Y8)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 3s - loss: 0.3484 - val_loss: 0.2073
# Epoch 2/300
#  - 0s - loss: 0.3123 - val_loss: 0.1814
# Epoch 3/300
#  - 0s - loss: 0.2826 - val_loss: 0.1576
# Epoch 4/300
#  - 0s - loss: 0.2509 - val_loss: 0.1359
# Epoch 5/300
#  - 0s - loss: 0.2238 - val_loss: 0.1163
# Epoch 6/300
#  - 0s - loss: 0.2006 - val_loss: 0.0987
# Epoch 7/300
#  - 0s - loss: 0.1795 - val_loss: 0.0832
# Epoch 8/300
#  - 0s - loss: 0.1502 - val_loss: 0.0695
# Epoch 9/300
#  - 0s - loss: 0.1383 - val_loss: 0.0576
# Epoch 10/300
#  - 0s - loss: 0.1260 - val_loss: 0.0474
# Epoch 11/300
#  - 0s - loss: 0.1100 - val_loss: 0.0389
# Epoch 12/300
#  - 0s - loss: 0.1138 - val_loss: 0.0321
# Epoch 13/300
#  - 0s - loss: 0.1030 - val_loss: 0.0268
# Epoch 14/300
#  - 0s - loss: 0.0859 - val_loss: 0.0228
# Epoch 15/300
#  - 0s - loss: 0.0848 - val_loss: 0.0200
# Epoch 16/300
#  - 0s - loss: 0.0730 - val_loss: 0.0182
# Epoch 17/300
# ...

# %%
y9_pred = lstm_model(Class9, Y9)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 3s - loss: 0.2847 - val_loss: 0.0769
# Epoch 2/300
#  - 0s - loss: 0.2675 - val_loss: 0.0654
# Epoch 3/300
#  - 0s - loss: 0.2396 - val_loss: 0.0553
# Epoch 4/300
#  - 0s - loss: 0.2253 - val_loss: 0.0462
# Epoch 5/300
#  - 0s - loss: 0.1974 - val_loss: 0.0383
# Epoch 6/300
#  - 0s - loss: 0.1786 - val_loss: 0.0315
# Epoch 7/300
#  - 0s - loss: 0.1746 - val_loss: 0.0259
# Epoch 8/300
#  - 0s - loss: 0.1682 - val_loss: 0.0215
# Epoch 9/300
#  - 0s - loss: 0.1480 - val_loss: 0.0181
# Epoch 10/300
#  - 0s - loss: 0.1149 - val_loss: 0.0158
# Epoch 11/300
#  - 0s - loss: 0.1041 - val_loss: 0.0145
# Epoch 12/300
#  - 0s - loss: 0.1113 - val_loss: 0.0142
# Epoch 13/300
#  - 0s - loss: 0.0938 - val_loss: 0.0147
# Epoch 14/300
#  - 0s - loss: 0.0944 - val_loss: 0.0161
# Epoch 15/300
#  - 0s - loss: 0.0983 - val_loss: 0.0180
# Epoch 16/300
#  - 0s - loss: 0.0767 - val_loss: 0.0202
# Epoch 17/300
# ...

# %%
y10_pred = lstm_model(Class10, Y10)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 3s - loss: 0.2551 - val_loss: 0.1647
# Epoch 2/300
#  - 0s - loss: 0.2325 - val_loss: 0.1432
# Epoch 3/300
#  - 0s - loss: 0.2068 - val_loss: 0.1235
# Epoch 4/300
#  - 0s - loss: 0.1881 - val_loss: 0.1059
# Epoch 5/300
#  - 0s - loss: 0.1675 - val_loss: 0.0903
# Epoch 6/300
#  - 0s - loss: 0.1383 - val_loss: 0.0764
# Epoch 7/300
#  - 0s - loss: 0.1296 - val_loss: 0.0643
# Epoch 8/300
#  - 0s - loss: 0.1134 - val_loss: 0.0541
# Epoch 9/300
#  - 0s - loss: 0.1063 - val_loss: 0.0460
# Epoch 10/300
#  - 0s - loss: 0.0858 - val_loss: 0.0396
# Epoch 11/300
#  - 0s - loss: 0.0855 - val_loss: 0.0348
# Epoch 12/300
#  - 0s - loss: 0.0757 - val_loss: 0.0316
# Epoch 13/300
#  - 0s - loss: 0.0595 - val_loss: 0.0297
# Epoch 14/300
#  - 0s - loss: 0.0663 - val_loss: 0.0289
# Epoch 15/300
#  - 0s - loss: 0.0655 - val_loss: 0.0290
# Epoch 16/300
#  - 0s - loss: 0.0787 - val_loss: 0.0294
# Epoch 17/300
# ...

# %%
fig = plt.figure(figsize = (20,10))

plt.plot(Y1['2018-08-26':] / Y1['2018-08-26':].sum()*100, label = labels[0])
plt.plot(Y2['2018-08-26':] / Y2['2018-08-26':].sum()*100, label = labels[1])
plt.plot(Y3['2018-08-26':] / Y3['2018-08-26':].sum()*100, label = labels[2])
plt.plot(Y4['2018-08-26':] / Y4['2018-08-26':].sum()*100, label = labels[3])
plt.plot(Y5['2018-08-26':] / Y5['2018-08-26':].sum()*100, label = labels[4])
plt.plot(Y6['2018-08-26':] / Y6['2018-08-26':].sum()*100, label = labels[5])
plt.plot(Y7['2018-08-26':] / Y7['2018-08-26':].sum()*100, label = labels[6])
plt.plot(Y8['2018-08-26':] / Y8['2018-08-26':].sum()*100, label = labels[7])
plt.plot(Y9['2018-08-26':] / Y9['2018-08-26':].sum()*100, label = labels[8])
plt.plot(Y10['2018-08-26':] / Y10['2018-08-26':].sum()*100, label = labels[9])
plt.xticks(['2018-08-26','2018-09-01','2018-09-10','2018-09-17','2018-09-25','2018-09-30'], fontsize = 12)

plt.legend(fontsize="x-large", ncol = 2)

# %%
# %matplotlib inline

# %%
plt.figure(figsize = (12,5))
plt.plot(y1_pred/y1_pred.sum()*100, label = labels[0])
plt.plot(y2_pred/y2_pred.sum()*100, label = labels[1])
plt.plot(y3_pred/y3_pred.sum()*100, label = labels[2])
plt.plot(y4_pred/y4_pred.sum()*100, label = labels[3])
plt.plot(y5_pred/y5_pred.sum()*100, label = labels[4])
plt.plot(y6_pred/y6_pred.sum()*100, label = labels[5])
plt.plot(y7_pred/y7_pred.sum()*100, label = labels[6])
plt.plot(y8_pred/y8_pred.sum()*100, label = labels[7])
plt.plot(y9_pred/y9_pred.sum()*100, label = labels[8])
plt.plot(y10_pred/y10_pred.sum()*100, label = labels[9])

plt.legend(fontsize="large", ncol = 2)
plt.xticks(['2018-08-26','2018-09-01','2018-09-10','2018-09-17','2018-09-25','2018-09-30'], fontsize = 12)
plt.show()

# %%
fig = plt.figure(figsize = (13,8))

plt.plot(Y1['2018-08-26':] , label = labels[0])
plt.plot(Y2['2018-08-26':] , label = labels[1])
plt.plot(Y3['2018-08-26':] , label = labels[2])
plt.plot(Y4['2018-08-26':] , label = labels[3])
plt.plot(Y5['2018-08-26':] , label = labels[4])
plt.plot(Y6['2018-08-26':] , label = labels[5])
plt.plot(Y7['2018-08-26':] , label = labels[6])
plt.plot(Y8['2018-08-26':] , label = labels[7])
plt.plot(Y9['2018-08-26':] , label = labels[8])
plt.plot(Y10['2018-08-26':] , label = labels[9])
plt.xticks(['2018-08-26','2018-09-02','2018-09-10','2018-09-17','2018-09-26','2018-09-22','2018-09-30'], fontsize = 12)
plt.vlines(x = '2018-09-02', ymin = 0, ymax = 8500, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-17', ymin = 0, ymax = 9950, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-26', ymin = 0, ymax = 9300, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-22', ymin = 0, ymax = 4500, linestyles='dashed', linewidth=1.5)
#plt.legend(fontsize="xx-large", bbox_to_anchor = (0.5, 1.5), ncol = 5)

# %%
fig = plt.figure(figsize = (13,7))

plt.plot(y1_pred , label = labels[0])
plt.plot(y2_pred , label = labels[1])
plt.plot(y3_pred , label = labels[2])
plt.plot(y4_pred , label = labels[3])
plt.plot(y5_pred , label = labels[4])
plt.plot(y6_pred , label = labels[5])
plt.plot(y7_pred , label = labels[6])
plt.plot(y8_pred , label = labels[7])
plt.plot(y9_pred , label = labels[8])
plt.plot(y10_pred , label = labels[9])

plt.xticks(['2018-08-26','2018-09-03','2018-09-10','2018-09-17','2018-09-22','2018-09-28'], fontsize = 12)
plt.vlines(x = '2018-09-03', ymin = 0, ymax = 7100, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-17', ymin = 0, ymax = 7800, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-28', ymin = 0, ymax = 7000, linestyles='dashed', linewidth=1.5)
plt.vlines(x = '2018-09-22', ymin = 0, ymax = 5000, linestyles='dashed', linewidth=1.5)

# %%
labels
# Out:
# ['furniture',
#  'electronic',
#  'pet',
#  'sports',
#  'food',
#  'travel',
#  'baby',
#  'kitchen',
#  'fashion',
#  'beauty']

# %% [markdown]
# ### 비율로 살펴보기

# %%
total = pd.concat( [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9, Y10], axis = 1 )
total.columns = labels
total.head()
# Out:
#             furniture  electronic  pet  sports  food  travel  baby  kitchen  \
# 2018-04-01       1306         693  640    4966  1422      66  4084     1995
# 2018-04-02       2280         648  813    4451  1535      69  4210     1910
# 2018-04-03       1615         623  548    3867  1295      75  4728     2036
# 2018-04-04       2079         611  662    3701  1370      48  3943     1419
# 2018-04-05       4097         530  667    3701  1542      65  3555     1946
#
#             fashion  beauty
# 2018-04-01    15446    5249
# 2018-04-02    13338    4396
# 2018-04-03    13514    3532
# 2018-04-04    12405    3674
# 2018-04-05    11739    3294

# %%
total_rate = pd.DataFrame(columns=total.columns)
total_rate
# Out:
# Empty DataFrame
# Columns: [furniture, electronic, pet, sports, food, travel, baby, kitchen, fashion, beauty]
# Index: []

# %%
for label in labels : 
    rate = []
    for i in range(1, len(total)) :
        rate.append(total[label][i]/total[label][i-1])
    total_rate[label] = rate

# %%
total_rate.index = mydate[1:]

# %%
total_rate.head()
# Out:
#             furniture  electronic       pet    sports      food    travel  \
# 2018-04-02   1.745789    0.935065  1.270312  0.896295  1.079466  1.045455
# 2018-04-03   0.708333    0.961420  0.674047  0.868794  0.843648  1.086957
# 2018-04-04   1.287307    0.980738  1.208029  0.957073  1.057915  0.640000
# 2018-04-05   1.970659    0.867430  1.007553  1.000000  1.125547  1.354167
# 2018-04-06   0.133268    0.935849  0.908546  1.066469  0.830091  1.076923
#
#                 baby   kitchen   fashion    beauty
# 2018-04-02  1.030852  0.957393  0.863525  0.837493
# 2018-04-03  1.123040  1.065969  1.013195  0.803458
# 2018-04-04  0.833968  0.696955  0.917937  1.040204
# 2018-04-05  0.901598  1.371388  0.946312  0.896570
# 2018-04-06  0.756681  0.760021  0.819150  0.870370

# %%
total_grade = pd.DataFrame(columns=total.columns, index = total_rate.index)
total_grade.head()
# Out:
#            furniture electronic  pet sports food travel baby kitchen fashion  \
# 2018-04-02       NaN        NaN  NaN    NaN  NaN    NaN  NaN     NaN     NaN
# 2018-04-03       NaN        NaN  NaN    NaN  NaN    NaN  NaN     NaN     NaN
# 2018-04-04       NaN        NaN  NaN    NaN  NaN    NaN  NaN     NaN     NaN
# 2018-04-05       NaN        NaN  NaN    NaN  NaN    NaN  NaN     NaN     NaN
# 2018-04-06       NaN        NaN  NaN    NaN  NaN    NaN  NaN     NaN     NaN
#
#            beauty
# 2018-04-02    NaN
# 2018-04-03    NaN
# 2018-04-04    NaN
# 2018-04-05    NaN
# 2018-04-06    NaN

# %%
for label in labels :
    total_grade[label] = '.'

    q2 = total_rate[label][total_rate[label]>=1].quantile([0.7,0.9])[0.7]
    q3 = total_rate[label][total_rate[label]>=1].quantile([0.7,0.9])[0.9]
    
    #q2보다 크면 BLUE 등급
    total_grade.loc[total_rate[label]>=q2, label] = 'GREEN'
    #q3보다 크면 GREEN 등급
    total_grade.loc[total_rate[label]>=q3, label] = 'BLUE'

# %%
total_grade.head()
# Out:
#            furniture electronic pet sports food travel baby kitchen fashion  \
# 2018-04-02         .          .   .      .    .      .    .       .       .
# 2018-04-03         .          .   .      .    .      .    .       .       .
# 2018-04-04         .          .   .      .    .      .    .       .       .
# 2018-04-05     GREEN          .   .      .    .      .    .   GREEN       .
# 2018-04-06         .          .   .  GREEN    .      .    .       .       .
#
#            beauty
# 2018-04-02      .
# 2018-04-03      .
# 2018-04-04      .
# 2018-04-05      .
# 2018-04-06      .

# %%
total_rate.loc[total_grade['fashion'] =='BLUE', 'fashion'].index
# Out:
# Index(['2018-04-22', '2018-05-01', '2018-06-03', '2018-06-06', '2018-07-01',
#        '2018-07-15', '2018-09-01', '2018-09-25', '2018-09-26'],
#       dtype='object')

# %%
total_rate['furniture'][total_rate['furniture']>=1].quantile([0.7,0.9])
# Out:
# 0.7    1.774773
# 0.9    2.937563
# Name: furniture, dtype: float64

# %%
q2 = total_rate['fashion'][total_rate['fashion']>=1].quantile([0.7,0.9])[0.7]
q3 = total_rate['fashion'][total_rate['fashion']>=1].quantile([0.7,0.9])[0.9]

# %%
total_rate.index
# Out:
# Index(['2018-04-02', '2018-04-03', '2018-04-04', '2018-04-05', '2018-04-06',
#        '2018-04-07', '2018-04-08', '2018-04-09', '2018-04-10', '2018-04-11',
#        ...
#        '2018-09-21', '2018-09-22', '2018-09-23', '2018-09-24', '2018-09-25',
#        '2018-09-26', '2018-09-27', '2018-09-28', '2018-09-29', '2018-09-30'],
#       dtype='object', length=182)

# %%
plt.figure(figsize = (18,10))
plt.plot(total_rate['fashion'], '0.5')
plt.hlines(y = q2, xmin = '2018-04-02', xmax='2018-09-30', linewidth=2.5, colors='green', linestyles='dashed')
plt.hlines(y = q3, xmin = '2018-04-02', xmax='2018-09-30', linewidth=2.5, colors='blue', linestyles='dashed')
plt.xticks(['2018-04-22', '2018-05-01', '2018-06-03', '2018-06-06', '2018-07-01','2018-07-15', '2018-09-01', '2018-09-25', '2018-09-26'],
          rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x172c9d58c88>,
# ...
#  <a list of 9 Text xticklabel objects>)
