# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
Class10 = pd.read_csv('C:/Users/wjssm/Desktop/lpoint/modeling/Class10.csv')
Class10['Date'] = pd.date_range('2018-04-01', '2018-09-30').strftime('%Y-%m-%d')
Class10['Date'] =pd.to_datetime(Class10['Date'])
Class10 = Class10.set_index('Date')
Class10.head()
# Out:
#             BUY_CT_sum  HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  \
# Date
# 2018-04-01        5249      76.096409         1723.511683      32.312954
# 2018-04-02        4396      66.356552         1404.668366      32.271150
# 2018-04-03        3532      66.140059         1417.485087      32.288606
# 2018-04-04        3674      58.337224         1334.197519      32.172503
# 2018-04-05        3294      65.217039         1498.213533      32.261663
#
#             beauty
# Date
# 2018-04-01      44
# 2018-04-02      44
# 2018-04-03      44
# 2018-04-04      44
# 2018-04-05      41

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    diff.append(dataset[0])
    for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
    return pd.Series(diff)

# inverse_difference
def inverse_difference(diff, interval=1):
    origin = list()
    origin.append(diff[0])
    for i in range(interval, len(diff)):
            value = diff[i] + origin[i - interval]
            origin.append(value)
    return pd.Series(origin)

# %%
Y = Class10['BUY_CT_sum']

# %%
#remove original Y
Class10.drop(columns=['BUY_CT_sum'],inplace=True)
Class10.rename(columns = {'furniture' : 'naver_click'}, inplace=True)
Class10.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  beauty
# Date
# 2018-04-01      76.096409         1723.511683      32.312954      44
# 2018-04-02      66.356552         1404.668366      32.271150      44
# 2018-04-03      66.140059         1417.485087      32.288606      44
# 2018-04-04      58.337224         1334.197519      32.172503      44
# 2018-04-05      65.217039         1498.213533      32.261663      41

# %%
def minmax(dataset):
    dataNorm=((dataset-dataset.min())/(dataset.max()-dataset.min()))
    return dataNorm

def inverse_minmax(norm,dataset):
    deNorm=norm*(dataset.max()-dataset.min())+dataset.min()
    return deNorm

# %% [markdown]
# #### 변수 조합

# %%
#TOT_SESS_HR_V_mean 역수
Class10['TOT_SESS_HR_V_mean'] = 1000/Class10['TOT_SESS_HR_V_mean']
Class10.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean  beauty
# Date
# 2018-04-01      76.096409            0.580211      32.312954      44
# 2018-04-02      66.356552            0.711912      32.271150      44
# 2018-04-03      66.140059            0.705475      32.288606      44
# 2018-04-04      58.337224            0.749514      32.172503      44
# 2018-04-05      65.217039            0.667462      32.261663      41

# %% [markdown]
# #### scaled

# %%
scaled_df1=minmax(Class10)
#(xi–mean(x))/stdev(x)
scaled_df1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean    beauty
# Date
# 2018-04-01       0.419589            0.155316       0.543926  0.681818
# 2018-04-02       0.190895            0.663233       0.533304  0.681818
# 2018-04-03       0.185811            0.638408       0.537739  0.681818
# 2018-04-04       0.002599            0.808251       0.508239  0.681818
# 2018-04-05       0.164139            0.491807       0.530893  0.545455

# %%
scaled_Y = minmax(Y)

scaled_df1 = pd.concat([scaled_df1, scaled_Y], axis = 1)
scaled_df1.rename(columns={'BUY_CT_sum':'Y'}, inplace=True)

scaled_df1.head()
# Out:
#             HITS_SEQ_mean  TOT_SESS_HR_V_mean  CLNT_AGE_mean    beauty  \
# Date
# 2018-04-01       0.419589            0.155316       0.543926  0.681818
# 2018-04-02       0.190895            0.663233       0.533304  0.681818
# 2018-04-03       0.185811            0.638408       0.537739  0.681818
# 2018-04-04       0.002599            0.808251       0.508239  0.681818
# 2018-04-05       0.164139            0.491807       0.530893  0.545455
#
#                    Y
# Date
# 2018-04-01  0.798749
# 2018-04-02  0.614754
# 2018-04-03  0.428387
# 2018-04-04  0.459016
# 2018-04-05  0.377049

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
#original data
plot_acf(Y, ax = plt.gca())

# %% [markdown]
# #### modeling

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# C:\Users\wjssm\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#scaled_data : scaled한 데이터. 사용하려는 변수 + 마지막 칼럼은 Y
#n : 사용하는 변수 개수

scaled_data = scaled_df1
n = 4

# %%
scaled_Y = scaled_data['Y']

values = scaled_df1.values
# frame as supervised learning
reframed = series_to_supervised(scaled_df1, 1, 1)
reframed.drop(reframed.columns[-(n+1):-1], axis=1,inplace = True)

# split into train and test sets
values = reframed.values
n_train = int(len(scaled_data)*0.8)
train = values[:n_train, :]
test = values[n_train:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=30, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 146 samples, validate on 36 samples
# Epoch 1/300
#  - 2s - loss: 0.2169 - val_loss: 0.1377
# Epoch 2/300
#  - 0s - loss: 0.1777 - val_loss: 0.1061
# Epoch 3/300
#  - 0s - loss: 0.1424 - val_loss: 0.0799
# Epoch 4/300
#  - 0s - loss: 0.1120 - val_loss: 0.0593
# Epoch 5/300
#  - 0s - loss: 0.0864 - val_loss: 0.0442
# Epoch 6/300
#  - 0s - loss: 0.0658 - val_loss: 0.0343
# Epoch 7/300
#  - 0s - loss: 0.0500 - val_loss: 0.0295
# Epoch 8/300
#  - 0s - loss: 0.0389 - val_loss: 0.0291
# Epoch 9/300
#  - 0s - loss: 0.0321 - val_loss: 0.0317
# Epoch 10/300
#  - 0s - loss: 0.0285 - val_loss: 0.0359
# Epoch 11/300
#  - 0s - loss: 0.0271 - val_loss: 0.0401
# Epoch 12/300
#  - 0s - loss: 0.0268 - val_loss: 0.0431
# Epoch 13/300
#  - 0s - loss: 0.0268 - val_loss: 0.0443
# Epoch 14/300
#  - 0s - loss: 0.0266 - val_loss: 0.0442
# Epoch 15/300
#  - 0s - loss: 0.0263 - val_loss: 0.0431
# Epoch 16/300
#  - 0s - loss: 0.0259 - val_loss: 0.0417
# Epoch 17/300
#  - 0s - loss: 0.0256 - val_loss: 0.0404
# Epoch 18/300
#  - 0s - loss: 0.0254 - val_loss: 0.0394
# Epoch 19/300
#  - 0s - loss: 0.0252 - val_loss: 0.0388
# Epoch 20/300
#  - 0s - loss: 0.0250 - val_loss: 0.0384
# Epoch 21/300
#  - 0s - loss: 0.0248 - val_loss: 0.0384
# Epoch 22/300
#  - 0s - loss: 0.0247 - val_loss: 0.0385
# Epoch 23/300
#  - 0s - loss: 0.0245 - val_loss: 0.0387
# Epoch 24/300
#  - 0s - loss: 0.0243 - val_loss: 0.0389
# Epoch 25/300
#  - 0s - loss: 0.0241 - val_loss: 0.0391
# Epoch 26/300
#  - 0s - loss: 0.0239 - val_loss: 0.0393
# Epoch 27/300
#  - 0s - loss: 0.0238 - val_loss: 0.0394
# Epoch 28/300
#  - 0s - loss: 0.0236 - val_loss: 0.0394
# Epoch 29/300
#  - 0s - loss: 0.0234 - val_loss: 0.0394
# Epoch 30/300
#  - 0s - loss: 0.0233 - val_loss: 0.0394
# Epoch 31/300
#  - 0s - loss: 0.0231 - val_loss: 0.0394
# Epoch 32/300
#  - 0s - loss: 0.0230 - val_loss: 0.0395
# Epoch 33/300
#  - 0s - loss: 0.0228 - val_loss: 0.0395
# Epoch 34/300
#  - 0s - loss: 0.0227 - val_loss: 0.0396
# Epoch 35/300
#  - 0s - loss: 0.0226 - val_loss: 0.0397
# Epoch 36/300
#  - 0s - loss: 0.0225 - val_loss: 0.0397
# Epoch 37/300
#  - 0s - loss: 0.0223 - val_loss: 0.0398
# Epoch 38/300
#  - 0s - loss: 0.0222 - val_loss: 0.0399
# Epoch 39/300
#  - 0s - loss: 0.0221 - val_loss: 0.0400
# Epoch 40/300
#  - 0s - loss: 0.0220 - val_loss: 0.0401
# Epoch 41/300
#  - 0s - loss: 0.0219 - val_loss: 0.0402
# Epoch 42/300
#  - 0s - loss: 0.0218 - val_loss: 0.0403
# Epoch 43/300
#  - 0s - loss: 0.0217 - val_loss: 0.0404
# Epoch 44/300
#  - 0s - loss: 0.0217 - val_loss: 0.0405
# Epoch 45/300
#  - 0s - loss: 0.0216 - val_loss: 0.0406
# Epoch 46/300
#  - 0s - loss: 0.0215 - val_loss: 0.0407
# Epoch 47/300
#  - 0s - loss: 0.0214 - val_loss: 0.0408
# Epoch 48/300
#  - 0s - loss: 0.0214 - val_loss: 0.0410
# Epoch 49/300
#  - 0s - loss: 0.0213 - val_loss: 0.0411
# Epoch 50/300
#  - 0s - loss: 0.0212 - val_loss: 0.0412
# Epoch 51/300
#  - 0s - loss: 0.0212 - val_loss: 0.0413
# Epoch 52/300
#  - 0s - loss: 0.0211 - val_loss: 0.0414
# Epoch 53/300
#  - 0s - loss: 0.0211 - val_loss: 0.0415
# Epoch 54/300
#  - 0s - loss: 0.0210 - val_loss: 0.0416
# Epoch 55/300
#  - 0s - loss: 0.0210 - val_loss: 0.0417
# Epoch 56/300
#  - 0s - loss: 0.0210 - val_loss: 0.0418
# Epoch 57/300
#  - 0s - loss: 0.0209 - val_loss: 0.0419
# Epoch 58/300
#  - 0s - loss: 0.0209 - val_loss: 0.0421
# Epoch 59/300
#  - 0s - loss: 0.0209 - val_loss: 0.0422
# Epoch 60/300
#  - 0s - loss: 0.0208 - val_loss: 0.0423
# Epoch 61/300
#  - 0s - loss: 0.0208 - val_loss: 0.0424
# Epoch 62/300
#  - 0s - loss: 0.0208 - val_loss: 0.0425
# Epoch 63/300
#  - 0s - loss: 0.0208 - val_loss: 0.0426
# Epoch 64/300
#  - 0s - loss: 0.0207 - val_loss: 0.0427
# Epoch 65/300
#  - 0s - loss: 0.0207 - val_loss: 0.0427
# Epoch 66/300
#  - 0s - loss: 0.0207 - val_loss: 0.0428
# Epoch 67/300
#  - 0s - loss: 0.0207 - val_loss: 0.0429
# Epoch 68/300
#  - 0s - loss: 0.0207 - val_loss: 0.0430
# Epoch 69/300
#  - 0s - loss: 0.0207 - val_loss: 0.0431
# Epoch 70/300
#  - 0s - loss: 0.0207 - val_loss: 0.0432
# Epoch 71/300
#  - 0s - loss: 0.0206 - val_loss: 0.0432
# Epoch 72/300
#  - 0s - loss: 0.0206 - val_loss: 0.0433
# Epoch 73/300
#  - 0s - loss: 0.0206 - val_loss: 0.0434
# Epoch 74/300
#  - 0s - loss: 0.0206 - val_loss: 0.0434
# Epoch 75/300
#  - 0s - loss: 0.0206 - val_loss: 0.0435
# Epoch 76/300
#  - 0s - loss: 0.0206 - val_loss: 0.0436
# Epoch 77/300
#  - 0s - loss: 0.0206 - val_loss: 0.0436
# Epoch 78/300
#  - 0s - loss: 0.0206 - val_loss: 0.0437
# Epoch 79/300
#  - 0s - loss: 0.0206 - val_loss: 0.0437
# Epoch 80/300
#  - 0s - loss: 0.0206 - val_loss: 0.0438
# Epoch 81/300
#  - 0s - loss: 0.0206 - val_loss: 0.0438
# Epoch 82/300
#  - 0s - loss: 0.0206 - val_loss: 0.0439
# Epoch 83/300
#  - 0s - loss: 0.0206 - val_loss: 0.0439
# Epoch 84/300
#  - 0s - loss: 0.0206 - val_loss: 0.0440
# Epoch 85/300
#  - 0s - loss: 0.0206 - val_loss: 0.0440
# Epoch 86/300
#  - 0s - loss: 0.0206 - val_loss: 0.0440
# Epoch 87/300
#  - 0s - loss: 0.0206 - val_loss: 0.0441
# Epoch 88/300
#  - 0s - loss: 0.0206 - val_loss: 0.0441
# Epoch 89/300
#  - 0s - loss: 0.0206 - val_loss: 0.0441
# Epoch 90/300
#  - 0s - loss: 0.0206 - val_loss: 0.0442
# Epoch 91/300
#  - 0s - loss: 0.0206 - val_loss: 0.0442
# Epoch 92/300
#  - 0s - loss: 0.0206 - val_loss: 0.0442
# Epoch 93/300
#  - 0s - loss: 0.0206 - val_loss: 0.0442
# Epoch 94/300
#  - 0s - loss: 0.0206 - val_loss: 0.0443
# Epoch 95/300
#  - 0s - loss: 0.0206 - val_loss: 0.0443
# Epoch 96/300
#  - 0s - loss: 0.0206 - val_loss: 0.0443
# Epoch 97/300
#  - 0s - loss: 0.0206 - val_loss: 0.0443
# Epoch 98/300
#  - 0s - loss: 0.0206 - val_loss: 0.0444
# Epoch 99/300
#  - 0s - loss: 0.0205 - val_loss: 0.0444
# Epoch 100/300
#  - 0s - loss: 0.0205 - val_loss: 0.0444
# Epoch 101/300
#  - 0s - loss: 0.0205 - val_loss: 0.0444
# Epoch 102/300
#  - 0s - loss: 0.0205 - val_loss: 0.0444
# Epoch 103/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 104/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 105/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 106/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 107/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 108/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 109/300
#  - 0s - loss: 0.0205 - val_loss: 0.0445
# Epoch 110/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 111/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 112/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 113/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 114/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 115/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 116/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 117/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 118/300
#  - 0s - loss: 0.0205 - val_loss: 0.0446
# Epoch 119/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 120/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 121/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 122/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 123/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 124/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 125/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 126/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 127/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 128/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 129/300
#  - 0s - loss: 0.0205 - val_loss: 0.0447
# Epoch 130/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 131/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 132/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 133/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 134/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 135/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 136/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 137/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 138/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 139/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 140/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 141/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 142/300
#  - 0s - loss: 0.0205 - val_loss: 0.0448
# Epoch 143/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 144/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 145/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 146/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 147/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 148/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 149/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 150/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 151/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 152/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 153/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 154/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 155/300
#  - 0s - loss: 0.0205 - val_loss: 0.0449
# Epoch 156/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 157/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 158/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 159/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 160/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 161/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 162/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 163/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 164/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 165/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 166/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 167/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 168/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 169/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 170/300
#  - 0s - loss: 0.0205 - val_loss: 0.0450
# Epoch 171/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 172/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 173/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 174/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 175/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 176/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 177/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 178/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 179/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 180/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 181/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 182/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 183/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 184/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 185/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 186/300
#  - 0s - loss: 0.0205 - val_loss: 0.0451
# Epoch 187/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 188/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 189/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 190/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 191/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 192/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 193/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 194/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 195/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 196/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 197/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 198/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 199/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 200/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 201/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 202/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 203/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 204/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 205/300
#  - 0s - loss: 0.0205 - val_loss: 0.0452
# Epoch 206/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 207/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 208/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 209/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 210/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 211/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 212/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 213/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 214/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 215/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 216/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 217/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 218/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 219/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 220/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 221/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 222/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 223/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 224/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 225/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 226/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 227/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 228/300
#  - 0s - loss: 0.0205 - val_loss: 0.0453
# Epoch 229/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 230/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 231/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 232/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 233/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 234/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 235/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 236/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 237/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 238/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 239/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 240/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 241/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 242/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 243/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 244/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 245/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 246/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 247/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 248/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 249/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 250/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 251/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 252/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 253/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 254/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 255/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 256/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 257/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 258/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 259/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 260/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 261/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 262/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 263/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 264/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 265/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 266/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 267/300
#  - 0s - loss: 0.0205 - val_loss: 0.0454
# Epoch 268/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 269/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 270/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 271/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 272/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 273/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 274/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 275/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 276/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 277/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 278/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 279/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 280/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 281/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 282/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 283/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 284/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 285/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 286/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 287/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 288/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 289/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 290/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 291/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 292/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 293/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 294/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 295/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 296/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 297/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 298/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 299/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455
# Epoch 300/300
#  - 0s - loss: 0.0205 - val_loss: 0.0455

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
true_Y = Y.values[n_train+1:].reshape(yhat.shape[0],1)

# %%
# invert scaling for forecast
dfhat = np.concatenate((true_Y,yhat), axis = 1)
#inv_dfhat = scaler.inverse_transform(dfhat)
inv_yhat = inverse_minmax(dfhat[:,1],dfhat[:,0])

# calculate RMSE
rmse = np.sqrt(mean_squared_error(true_Y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 705.573

# %%
plt.figure(figsize=(10,5))
plt.plot(true_Y, label = 'y_true')
plt.plot(inv_yhat,label = 'y_hat')
plt.legend()

# %%
inv_yhat = pd.Series(inv_yhat)
inv_yhat.index = Y[n_train+1:,].index

# %%
plt.figure(figsize=(10,5))
plt.plot(Y, label = 'y_true')
plt.plot(inv_yhat,label = 'y_hat', c='r')
plt.legend()
